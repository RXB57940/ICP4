# %%
#read the data
import pandas as pd
path_to_csv = 'C:/Users/rosha/OneDrive/Desktop/diabetes.csv'

# %%
import keras
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv(path_to_csv, header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)

# %%
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(4, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# c:\Users\rosha\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6507 - loss: 16.6253
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6885 - loss: 7.0291
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6461 - loss: 3.3710
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6398 - loss: 1.1940
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.4739 - loss: 0.8131
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.3940 - loss: 0.7160
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.3695 - loss: 0.7472
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.4237 - loss: 0.6941
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.3939 - loss: 0.7257
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.4062 - loss: 0.6930
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.3846 - loss: 0.6785
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.4868 - loss: 0.6768
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6500 - loss: 0.6919
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.6342 - loss: 0.6926
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6755 - loss: 0.6902
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6587 - loss: 0.6763
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6611 - loss: 0.6718
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6684 - loss: 0.6692
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6379 - loss: 0.7024
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6637 - loss: 0.6583
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6635 - loss: 0.6634
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6804 - loss: 0.6556
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6801 - loss: 0.6811
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6745 - loss: 0.6474
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6754 - loss: 0.6470
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6979 - loss: 0.6373
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.6444 - loss: 0.6772
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6610 - loss: 0.6509
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6474 - loss: 0.6562
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6437 - loss: 0.6491
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6463 - loss: 0.6515
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6806 - loss: 0.6279
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6910 - loss: 0.6458
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6721 - loss: 0.6409
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6736 - loss: 0.6345
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6616 - loss: 0.6405
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6593 - loss: 0.6379
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6351 - loss: 0.6386
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6330 - loss: 0.6441
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6346 - loss: 0.6501
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6165 - loss: 0.6569
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6930 - loss: 0.6237
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6686 - loss: 0.6190
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6402 - loss: 0.6186
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6313 - loss: 0.6340
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6492 - loss: 0.6226
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6649 - loss: 0.5989
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6433 - loss: 0.6106
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6669 - loss: 0.5818
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6953 - loss: 0.5830
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6467 - loss: 0.5812
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6329 - loss: 0.6245
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6576 - loss: 0.5814
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6259 - loss: 0.5954
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6591 - loss: 0.5934
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6707 - loss: 0.5913
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6694 - loss: 0.6005
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6573 - loss: 0.5915
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6307 - loss: 0.6033
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6614 - loss: 0.5780
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6530 - loss: 0.5908
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6699 - loss: 0.5964
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6810 - loss: 0.5605
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6552 - loss: 0.5735
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6541 - loss: 0.5858
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6502 - loss: 0.5811
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6582 - loss: 0.6034
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6413 - loss: 0.6064
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6753 - loss: 0.5818
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6562 - loss: 0.5833
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6867 - loss: 0.5698
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6276 - loss: 0.6229
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6406 - loss: 0.6315
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6623 - loss: 0.5859
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6726 - loss: 0.6013
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6702 - loss: 0.6112
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6250 - loss: 0.6052
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6487 - loss: 0.6070
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6183 - loss: 0.5900
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6422 - loss: 0.5801
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6628 - loss: 0.5962
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acc: 0.6815 - loss: 0.5618
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6466 - loss: 0.5756
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6641 - loss: 0.5623
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6802 - loss: 0.5649
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6762 - loss: 0.5612
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6675 - loss: 0.5685
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6832 - loss: 0.5450
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6437 - loss: 0.6288
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6626 - loss: 0.5794
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6900 - loss: 0.5734
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6455 - loss: 0.5968
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6564 - loss: 0.5930
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6865 - loss: 0.5775
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6139 - loss: 0.5975
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6859 - loss: 0.5610
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6638 - loss: 0.5782
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6884 - loss: 0.5715
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6510 - loss: 0.5791
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6517 - loss: 0.5822
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_54 (Dense)                │ (None, 20)             │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 4)              │            84 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 809 (3.16 KB)
#  Trainable params: 269 (1.05 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 540 (2.11 KB)
# None
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.6463 - loss: 0.5902
# [0.6055772304534912, 0.6197916865348816]

# %%
#read the data
import pandas as pd
path_to_csv = 'C:/Users/rosha/OneDrive/Desktop/breas cancer.csv'

dataset = pd.read_csv(path_to_csv)
print(dataset.info())  # Check data types
print(dataset.isna().sum())  # Check for NaNs (missing values)
dataset['id'] = pd.to_numeric(dataset['id'], errors='coerce')
dataset['radius_mean'] = pd.to_numeric(dataset['radius_mean'], errors='coerce')
dataset['texture_mean'] = pd.to_numeric(dataset['texture_mean'], errors='coerce')
dataset['perimeter_mean'] = pd.to_numeric(dataset['perimeter_mean'], errors='coerce')
dataset['area_mean'] = pd.to_numeric(dataset['area_mean'], errors='coerce')
dataset['smoothness_mean'] = pd.to_numeric(dataset['smoothness_mean'], errors='coerce')
dataset['compactness_mean'] = pd.to_numeric(dataset['compactness_mean'], errors='coerce')
dataset['concavity_mean'] = pd.to_numeric(dataset['concavity_mean'], errors='coerce')
dataset['concave points_mean'] = pd.to_numeric(dataset['concave points_mean'], errors='coerce')
dataset['symmetry_mean'] = pd.to_numeric(dataset['symmetry_mean'], errors='coerce')
dataset['fractal_dimension_mean'] = pd.to_numeric(dataset['fractal_dimension_mean'], errors='coerce')
dataset['radius_se'] = pd.to_numeric(dataset['radius_se'], errors='coerce')
dataset['texture_se'] = pd.to_numeric(dataset['texture_se'], errors='coerce')
dataset['perimeter_se'] = pd.to_numeric(dataset['perimeter_se'], errors='coerce')
dataset['area_se'] = pd.to_numeric(dataset['area_se'], errors='coerce')
dataset['smoothness_se'] = pd.to_numeric(dataset['smoothness_se'], errors='coerce')
dataset['compactness_se'] = pd.to_numeric(dataset['compactness_se'], errors='coerce')
dataset['concavity_se'] = pd.to_numeric(dataset['concavity_se'], errors='coerce')
dataset['concave points_se'] = pd.to_numeric(dataset['concave points_se'], errors='coerce')
dataset['symmetry_se'] = pd.to_numeric(dataset['symmetry_se'], errors='coerce')
dataset['fractal_dimension_se'] = pd.to_numeric(dataset['fractal_dimension_se'], errors='coerce')
dataset['radius_worst'] = pd.to_numeric(dataset['radius_worst'], errors='coerce')
dataset['texture_worst'] = pd.to_numeric(dataset['texture_worst'], errors='coerce')

dataset['perimeter_worst'] = pd.to_numeric(dataset['perimeter_worst'], errors='coerce')
dataset['area_worst'] = pd.to_numeric(dataset['area_worst'], errors='coerce')
dataset['smoothness_worst'] = pd.to_numeric(dataset['smoothness_worst'], errors='coerce')
dataset['compactness_worst'] = pd.to_numeric(dataset['compactness_worst'], errors='coerce')
dataset['concavity_worst'] = pd.to_numeric(dataset['concavity_worst'], errors='coerce')
dataset['concave points_worst'] = pd.to_numeric(dataset['concave points_worst'], errors='coerce')
dataset['symmetry_worst'] = pd.to_numeric(dataset['symmetry_worst'], errors='coerce')
dataset['fractal_dimension_worst'] = pd.to_numeric(dataset['fractal_dimension_worst'], errors='coerce')
#dataset['concave points_worst'] = pd.to_numeric(dataset['concave points_worst'], errors='coerce')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB
# None
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

# Load dataset
dataset = pd.read_csv("C:/Users/rosha/OneDrive/Desktop/Breas Cancer.csv")  # Ensure file exists
print(dataset.head())  # Debugging step

# Drop 'id' column if it exists
if 'id' in dataset.columns:
    dataset.drop(columns=['id'], inplace=True)

# Convert all columns to numeric (handle non-numeric values)
dataset = dataset.apply(pd.to_numeric, errors='coerce')

# Handle missing values: Fill NaNs with column means
dataset.fillna(dataset.mean(), inplace=True)

# Debugging: Check dataset shape
print(dataset.shape)

# Ensure target column exists (check last column manually if needed)
if dataset.shape[1] < 2:
    raise ValueError("Dataset does not have enough columns. Check the target variable.")

# Split into features (X) and target (Y)
X = dataset.iloc[:, :-1]  # Features (all columns except last)
Y = dataset.iloc[:, -1]   # Target (last column)

# Check shape before train-test split
print(X.shape, Y.shape)  # Ensure non-zero samples

# Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)

# Check if train-test split is valid
if X_train.shape[0] == 0:
    raise ValueError("Train set is empty! Adjust test_size or check dataset preprocessing.")

# Set random seed
np.random.seed(155)

# Create Neural Network Model
my_nn = Sequential()
my_nn.add(Dense(30, input_dim=X.shape[1], activation='relu'))  # First hidden layer
my_nn.add(Dense(20, activation='relu'))  # Second hidden layer
my_nn.add(Dense(10, activation='relu'))  # Third hidden layer
my_nn.add(Dense(5, activation='relu'))  # Fourth hidden layer
my_nn.add(Dense(1, activation='sigmoid'))  # Output layer

# Compile model
my_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Train model
my_nn_fitted = my_nn.fit(X_train, Y_train, epochs=150, verbose=1, validation_split=0.2)

# Print model summary
print(my_nn.summary())

# Evaluate model on test data
loss, accuracy = my_nn.evaluate(X_test, Y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]
# (569, 32)
# (569, 31) (569,)
# c:\Users\rosha\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 2/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 3/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 4/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 5/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 6/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 7/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 8/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 9/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 10/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 11/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 12/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 13/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 14/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 15/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 16/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 17/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 18/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 19/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 20/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 21/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 22/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 23/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 24/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 25/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 26/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 27/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 28/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 29/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 30/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 31/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 32/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 33/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 34/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 35/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 36/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 37/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 38/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 39/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 40/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 41/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 42/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 43/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 44/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 45/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 46/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 47/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 48/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 49/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 50/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 51/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 52/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 53/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 54/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 55/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 56/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 57/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 58/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 59/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 60/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 61/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 62/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 63/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 64/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 65/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 66/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 67/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 68/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 69/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 70/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 71/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 72/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 73/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 74/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 75/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 76/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 77/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 78/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 79/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 80/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 81/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 82/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 83/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 84/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 85/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 86/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 87/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 88/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 89/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 90/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 91/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 92/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 93/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 94/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 95/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 96/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 97/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 98/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 99/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 100/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 101/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 102/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 103/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 104/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 105/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 106/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 107/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 108/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 109/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 110/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 111/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 112/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 113/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 114/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 115/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 116/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 117/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 118/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 119/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 120/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 121/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 122/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 123/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 124/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 125/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 126/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 127/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 128/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 129/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 130/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 131/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 132/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 133/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 134/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 135/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 136/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 137/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 138/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 139/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 140/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 141/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 142/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 143/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 144/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 145/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 146/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 147/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 148/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 149/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Epoch 150/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - acc: 0.0000e+00 - loss: nan - val_acc: 0.0000e+00 - val_loss: nan
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 30)             │           960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 20)             │           620 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,555 (21.70 KB)
#  Trainable params: 1,851 (7.23 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,704 (14.47 KB)
# None
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0000e+00 - loss: nan
# Test Accuracy: 0.0000

# %%
#read the data
data = pd.read_csv('C:/Users/rosha/OneDrive/Desktop/breastcancer.csv')

# %%
path_to_csv = 'C:/Users/rosha/OneDrive/Desktop/breastcancer.csv'

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# load dataset
cancer_data = load_breast_cancer()
X_train, X_test, Y_train, Y_test = train_test_split(cancer_data.data, cancer_data.target,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_nn = Sequential() # create model
my_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer 1
my_nn.add(Dense(1, activation='sigmoid')) # output layer
my_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_nn_fitted = my_nn.fit(X_train, Y_train, epochs=100,
                         initial_epoch=0)
print(my_nn.summary())
print(my_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# c:\Users\rosha\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.4399 - loss: 99.4228
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.3643 - loss: 63.7971
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acc: 0.3941 - loss: 22.9518
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.5960 - loss: 7.1191
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.6096 - loss: 2.7649
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.7477 - loss: 2.0099
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.7669 - loss: 1.2917
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.8263 - loss: 1.0109
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.8043 - loss: 0.9003
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.8513 - loss: 0.6979
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.
20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9948 - loss: 0.0151 - val_accuracy: 0.9829 - val_loss: 0.0782

# %%
# plot the training and validation accuracy and loss curves
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.show()

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# create a simple neural network model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# train the model
model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
          epochs=20, batch_size=128)
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8630 - loss: 0.4546 - val_accuracy: 0.9617 - val_loss: 0.1226
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9683 - loss: 0.1044 - val_accuracy: 0.9743 - val_loss: 0.0817
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9781 - loss: 0.0688 - val_accuracy: 0.9787 - val_loss: 0.0715
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9825 - loss: 0.0530 - val_accuracy: 0.9777 - val_loss: 0.0669
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9857 - loss: 0.0450 - val_accuracy: 0.9801 - val_loss: 0.0642
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9877 - loss: 0.0372 - val_accuracy: 0.9813 - val_loss: 0.0643
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9891 - loss: 0.0337 - val_accuracy: 0.9799 - val_loss: 0.0683
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9905 - loss: 0.0287 - val_accuracy: 0.9817 - val_loss: 0.0652
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9904 - loss: 0.0284 - val_accuracy: 0.9820 - val_loss: 0.0656
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9931 - loss: 0.0210 - val_accuracy: 0.9823 - val_loss: 0.0688
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9933 - loss: 0.0211 - val_accuracy: 0.9812 - val_loss: 0.0731
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9930 - loss: 0.0199 - val_accuracy: 0.9812 - val_loss: 0.0721
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9931 - loss: 0.0203 - val_accuracy: 0.9825 - val_loss: 0.0709
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9935 - loss: 0.0193 - val_accuracy: 0.9810 - val_loss: 0.0753
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.9945 - loss: 0.0159 - val_accuracy: 0.9843 - val_loss: 0.0650
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9940 - loss: 0.0168 - val_accuracy: 0.9817 - val_loss: 0.0794
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9948 - loss: 0.0155 - val_accuracy: 0.9814 - val_loss: 0.0853
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9955 - loss: 0.0140 - val_accuracy: 0.9823 - val_loss: 0.0757
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9956 - loss: 0.0139 - val_accuracy: 0.9827 - val_loss: 0.0800
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9956 - loss: 0.0141 - val_accuracy: 0.9830 - val_loss: 0.0858

# %%
# plot one of the images in the test data
plt.imshow(x_test[0], cmap='gray')
plt.show()

# make a prediction on the image using the trained model
prediction = model.predict(x_test[0].reshape(1, -1))
print('Model prediction:', np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Model prediction: 7

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# %%
# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0720, Test accuracy: 0.9790
# 1 hidden layer with sigmoid - Test loss: 0.0582, Test accuracy: 0.9823
# 2 hidden layers with tanh - Test loss: 0.0761, Test accuracy: 0.9788
# 2 hidden layers with sigmoid - Test loss: 0.0672, Test accuracy: 0.9828

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1919, Test accuracy: 0.9402
# 1 hidden layer with sigmoid - Test loss: 0.1460, Test accuracy: 0.9552
# 2 hidden layers with tanh - Test loss: 0.1422, Test accuracy: 0.9560
# 2 hidden layers with sigmoid - Test loss: 0.1125, Test accuracy: 0.9631
